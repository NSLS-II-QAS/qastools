# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "/nsls2/xf07bm/data/pizza_box_data/2018/04/17/an_95ff14"
#filename = ""

gg=np.loadtxt(filename)

gg.shape
# Out:
# (33967, 4)

# %%
plt.figure(0);

plt.plot(gg[:, 3])
# Out:
# <img src="data:image/png;base64,..." width="640">
